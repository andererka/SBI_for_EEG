# %% [markdown]
# ## Toy example: Inferring the mean of Gaussians
#
# #### comparing the multi-round SNPE approach against our new incremental approach.
#
# Goal of this little toy example is to show that provided our parameters are independent of each other, we need less simulations to derive a good approximation of our parameters.

# %%
import sys
sys.path.append('../code/')

import utils
from utils.helpers import get_time
from utils import inference

from utils.sbi_modulated_functions import Combined


from utils.helpers import get_time

from utils.simulation_wrapper import SimulationWrapper


# sbi
from sbi import utils as utils
from sbi import analysis as analysis
from sbi.inference.base import infer
from sbi.inference import SNPE, prepare_for_sbi, simulate_for_sbi
from sbi.inference import SNPE_C

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

def Gaussian(thetas, normal_noise=0.1):
    
    gauss_list = []
    
    for theta in thetas:
    
        mu, sigma = theta, normal_noise # mean and standard deviation

        s = np.random.normal(mu, sigma, 1)
        
        gauss_list.append(s[0])
        
    gauss_obs = torch.tensor(gauss_list)
    
    return gauss_obs

# %%
true_thetas = torch.tensor([[3, 0.5, 6, 20, 10, 90, 55, 27]])



gauss = Gaussian(true_thetas[0], 0.5)

# %%
print(gauss)
# Out:
# tensor([ 3.3080,  0.5207,  6.1393, 19.4982, 10.0987, 89.7396, 55.1712, 26.2474],
#        dtype=torch.float64)

# %%
def sum_stats(gauss):
    #gauss = torch.from_numpy(gauss)
    mean = torch.mean(gauss, dim=1)
    std = torch.std(gauss, dim=1)
    stats = torch.stack([mean, std], dim=1)
    
    return stats

for gauss in Gaussians:
    print(sum_stats(gauss))

# %%
prior_max = [100] * 8
prior_min = [0] * 8

print(prior_max)
# Out:
# [100, 100, 100, 100, 100, 100, 100, 100]

# %% [markdown]
# ### Starting with the Multi-round SNPE approach

# %%
from sbi import utils as utils

num_simulations = 100

prior = utils.torchutils.BoxUniform(low=prior_min, high = prior_max)
inf = SNPE_C(prior, density_estimator="mdn")
simulator_stats, prior = prepare_for_sbi(Gaussian, prior)

proposal = prior

for i in range(8):

    theta, x = simulate_for_sbi(
        simulator_stats,
        proposal=proposal,
        num_simulations=num_simulations,
        num_workers=8,
    )
    
    #x = sum_stats(x_without)


    inf = inf.append_simulations(theta, x)
    density_estimator = inf.train()

    posterior = inf.build_posterior(density_estimator)
    
    obs_real = Gaussian(true_thetas[0])
    
    print(obs_real)

    
    proposal = posterior.set_default_x(obs_real)
# Out:
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Neural network successfully converged after 115 epochs.
# tensor([ 2.8727,  0.4985,  6.0386, 20.0575, 10.0006, 90.0550, 54.9757, 27.0132],
#        dtype=torch.float64)
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Neural network successfully converged after 189 epochs.
# tensor([ 2.9429,  0.5453,  6.0027, 19.7676,  9.9593, 89.7941, 54.8638, 27.0155],
#        dtype=torch.float64)
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Neural network successfully converged after 50 epochs.
# tensor([ 2.9975,  0.4351,  6.1478, 19.8991,  9.8997, 89.9881, 54.8677, 27.0094],
#        dtype=torch.float64)
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Neural network successfully converged after 55 epochs.
# tensor([ 2.8845,  0.4608,  6.0399, 19.9828, 10.0637, 89.9387, 54.9326, 26.9069],
#        dtype=torch.float64)
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Neural network successfully converged after 42 epochs.
# tensor([ 3.0203,  0.5965,  6.0689, 20.0062,  9.8791, 90.1291, 54.8188, 27.0893],
#        dtype=torch.float64)
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Neural network successfully converged after 36 epochs.
# tensor([ 2.8648,  0.6022,  6.1168, 19.7772, 10.0633, 89.8659, 54.9029, 27.0660],
#        dtype=torch.float64)
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Neural network successfully converged after 89 epochs.
# tensor([ 3.0947,  0.5596,  5.9243, 20.1275,  9.8198, 90.0856, 54.8842, 26.8215],
#        dtype=torch.float64)
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# Running 100 simulations in 100 batches.:   0%|          | 0/100 [00:00<?, ?it/s]
# Neural network successfully converged after 110 epochs.
# tensor([ 3.0509,  0.4492,  6.0174, 20.0416,  9.9395, 89.9016, 54.9981, 26.9959],
#        dtype=torch.float64)

# %%
num_samples = 10000

samples = posterior.sample((num_samples,), x=obs_real)
# Out:
# Drawing 10000 posterior samples:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
list_min = torch.min(samples, 0)[0]
list_max = torch.max(samples, 0)[0]

print(list_min)

print(list_max)

diff = torch.abs(list_max - list_min) * 0.05

print(diff)

list_min = list(list_min - diff)
list_max = list(list_max + diff)

limits = [list(tup) for tup in zip(list_min, list_max)]
# Out:
# tensor([4.3603e-04, 1.6188e-04, 4.4255e-03, 1.6863e+01, 5.0206e+00, 8.5619e+01,
#         4.7648e+01, 2.5147e+01])
# tensor([ 7.4089,  5.4325, 13.6890, 23.3434, 15.2682, 94.4536, 61.0516, 31.6522])
# tensor([0.3704, 0.2716, 0.6842, 0.3240, 0.5124, 0.4417, 0.6702, 0.3253])

# %%
#limits = [list(tup) for tup in zip(prior_min, prior_max)]
true_thetas = torch.tensor([[3, 0.5, 6, 20, 10, 90, 55, 27]])
parameter_names = ['t1', 't2', 't3', 't4', 't5', 't6', 't7', 't8']

fig, axes = analysis.pairplot(
    samples,
    limits=limits,
    ticks=limits,
    figsize=(20, 20),
    points=true_thetas,
    points_offdiag={"markersize": 6},
    points_colors="r",
    tick_labels=np.round(limits,2),
    labels=parameter_names,
)

# %% [markdown]
# ### Now we do the same, but with the incremental approach:

# %%
import datetime
range_list = [1,2,3,4,5,6,7,8]
num_simulations = 1000

true_thetas = torch.tensor([[3, 0.5, 6, 20, 10, 90, 55, 27]])

prior_i = utils.torchutils.BoxUniform(low=prior_min[0:1], high = prior_max[0:1])
inf = SNPE_C(prior_i, density_estimator="mdn")
simulator_stats, prior_i = prepare_for_sbi(Gaussian, prior_i)

obs_real = Gaussian([true_thetas[0, 0]])

obs_real_stats = sum_stats(torch.tensor([obs_real]))

print(obs_real_stats)

for index in range(len(range_list)-1):

    ## i defines number of parameters to be inferred, j indicates how many parameters 
    #to come in the next round
    i = range_list[index]
    j = range_list[index+1]

    print(i, j)


    start_time = datetime.datetime.now()

    theta, x_without =  simulate_for_sbi(
        simulator_stats,
        proposal=prior_i,
        num_simulations=num_simulations,
        num_workers=8,
        
    )


    x = sum_stats(x_without)
    inf = inf.append_simulations(theta, x)
    neural_dens = inf.train()

    posterior = inf.build_posterior(neural_dens)
    
    if i < 2:
        obs_real = Gaussian([true_thetas[0, 0:i]])
        
    else:
        obs_real = Gaussian(true_thetas[0, 0:i])

    obs_real_stats = sum_stats(torch.tensor([obs_real]))

    proposal1 = posterior.set_default_x(obs_real_stats)

    next_prior = utils.torchutils.BoxUniform(low=prior_min[i:j], high=prior_max[i:j])

    combined_prior = Combined(proposal1, next_prior, number_params_1=i)


    ## set inf for next round:
    inf = SNPE_C(combined_prior, density_estimator="mdn")


    ## set combined prior to be the new prior_i:
    prior_i = combined_prior
    
    finish_time = datetime.datetime.now()
    
    diff = finish_time - start_time
    
    print('took ', diff, ' for this step')
# Out:
# tensor([[2.9977, 0.0987]], dtype=torch.float64)

# %%
prior_i.sample((100,)).shape
# Out:
# Drawing 100 posterior samples:   0%|          | 0/100 [00:00<?, ?it/s]
# theta shape torch.Size([100, 8])
# torch.Size([100, 8])

# %%
    
theta, x_without =  simulate_for_sbi(
    simulator_stats,
    proposal=prior_i,
    num_simulations=num_simulations,
    num_workers=8,

)


x = sum_stats(x_without)
inf = inf.append_simulations(theta, x)
neural_dens = inf.train()

posterior = inf.build_posterior(neural_dens)
# Out:
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# theta shape torch.Size([1000, 8])
# Running 1000 simulations in 1000 batches.:   0%|          | 0/1000 [00:00<?, ?it/s]
# Neural network successfully converged after 63 epochs.

# %%
obs_real = Gaussian(true_thetas[0, :])

print(obs_real.shape)

obs_real_stats = sum_stats(torch.tensor([obs_real]))

print(obs_real_stats.shape)

posterior.set_default_x(obs_real_stats)
# Out:
# (8000,)
# torch.Size([1, 2])

# %%
num_samples = 10000

obs_real_stats = posterior_snpe3.default_x

samples = posterior_snpe3.sample((num_samples,), x=obs_real_stats)
# Out:
# Drawing 10000 posterior samples:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
samples.shape
# Out:
# torch.Size([10000, 8])

# %%
list_min = torch.min(samples, 0)[0]
list_max = torch.max(samples, 0)[0]

print(list_min)

print(list_max)

diff = torch.abs(list_max - list_min) * 0.1

print(diff)

list_min = list(list_min - diff)
list_max = list(list_max + diff)

limits = [list(tup) for tup in zip(list_min, list_max)]
# Out:
# tensor([2.1389e+00, 1.1472e-02, 1.3265e-02, 3.5404e-03, 2.3574e-04, 1.1865e-01,
#         0.0000e+00, 5.4475e-04])
# tensor([99.9989, 49.1416, 44.0636, 46.9337, 29.9907, 71.7071, 69.4470, 59.6616])
# tensor([9.7860, 4.9130, 4.4050, 4.6930, 2.9990, 7.1588, 6.9447, 5.9661])

# %%
true_thetas = torch.tensor([[3, 0.5, 6, 20, 10, 90, 55, 27]])
parameter_names = ['t1', 't2', 't3', 't4', 't5', 't6', 't7', 't8']

fig, axes = analysis.pairplot(
    samples,
    limits=limits,
    ticks=np.round(limits, 2),
    figsize=(20, 20),
    points=true_thetas,
    points_offdiag={"markersize": 6},
    points_colors="r",
    tick_labels=np.round(limits,2),
    labels=parameter_names,
)

# %% [markdown]
# ### Larger comparison with KL-divergence between analytic and inferred posterior

# %%
from math import log2

def kl_divergence(p, q):
    return sum(p[i] * log2(p[i]/q[i]) for i in range(len(p)))

# %%
### analytic posterior:

analytic = torch.distributions.normal.Normal(true_thetas, 0.1)

# %% [markdown]
# ### Calculate posterior for different number of simulations: 1k,  3k, 5k, 10k

# %% [markdown]
# ### starting with multi-round snpe

# %%
num_simulations_list = [100, 1000, 10000]

prior = utils.torchutils.BoxUniform(low=prior_min, high = prior_max)
inf = SNPE_C(prior, density_estimator="mdn")
simulator_stats, prior = prepare_for_sbi(Gaussian, prior)

proposal = prior

posterior_snpe_list = []

for num_simulations in num_simulations_list:

    for i in range(8):

        theta, x_without = simulate_for_sbi(
            simulator_stats,
            proposal=proposal,
            num_simulations=num_simulations,
            num_workers=8,
        )

        x = sum_stats(x_without)


        inf = inf.append_simulations(theta, x)
        density_estimator = inf.train()

        posterior = inf.build_posterior(density_estimator)

        obs_real = Gaussian(true_thetas[0])

        obs_real_stats = sum_stats(torch.tensor([obs_real]))

        proposal = posterior.set_default_x(obs_real_stats)

    posterior_snpe = posterior
    
    posterior_snpe_list.append(posterior_snpe)
# Out:
# Running 100000 simulations in 100000 batches.:   0%|          | 0/100000 [00:00<?, ?it/s]
# Neural network successfully converged after 74 epochs.
# Drawing 100000 posterior samples:   0%|          | 0/100000 [00:00<?, ?it/s]
# Running 100000 simulations in 100000 batches.:   0%|          | 0/100000 [00:00<?, ?it/s]
# Neural network successfully converged after 72 epochs.
# Drawing 100000 posterior samples:   0%|          | 0/100000 [00:00<?, ?it/s]
# Running 100000 simulations in 100000 batches.:   0%|          | 0/100000 [00:00<?, ?it/s]
# Neural network successfully converged after 32 epochs.
# Drawing 100000 posterior samples:   0%|          | 0/100000 [00:00<?, ?it/s]
# Running 100000 simulations in 100000 batches.:   0%|          | 0/100000 [00:00<?, ?it/s]
# Training neural network. Epochs trained:  15

# %% [markdown]
# ### For incremental approach:

# %%
range_list = [1,2,3,4,5,6,7,8]

import datetime
true_thetas = torch.tensor([[3, 0.5, 6, 20, 10, 90, 55, 27]])

posterior_incremental_list = []


for num_simulations in num_simulations_list:
    
    prior_i = utils.torchutils.BoxUniform(low=prior_min[0:1], high = prior_max[0:1])
    
    inf = SNPE_C(prior_i, density_estimator="mdn")
    simulator_stats, prior_i = prepare_for_sbi(Gaussian, prior_i)

    obs_real = Gaussian([true_thetas[0, 0]])

    obs_real_stats = sum_stats(torch.tensor([obs_real]))

    for index in range(len(range_list)-1):

        ## i defines number of parameters to be inferred, j indicates how many parameters 
        #to come in the next round
        i = range_list[index]
        j = range_list[index+1]

        print(i, j)


        start_time = datetime.datetime.now()

        theta, x_without =  simulate_for_sbi(
            simulator_stats,
            proposal=prior_i,
            num_simulations=num_simulations,
            num_workers=8,

        )


        x = sum_stats(x_without)
        inf = inf.append_simulations(theta, x)
        neural_dens = inf.train()

        posterior = inf.build_posterior(neural_dens)

        if i < 2:
            obs_real = Gaussian([true_thetas[0, 0:i]])

        else:
            obs_real = Gaussian(true_thetas[0, 0:i])

        obs_real_stats = sum_stats(torch.tensor([obs_real]))

        proposal1 = posterior.set_default_x(obs_real_stats)

        next_prior = utils.torchutils.BoxUniform(low=prior_min[i:j], high=prior_max[i:j])

        combined_prior = Combined(proposal1, next_prior, number_params_1=i)


        ## set inf for next round:
        inf = SNPE_C(combined_prior, density_estimator="mdn")


        ## set combined prior to be the new prior_i:
        prior_i = combined_prior

        finish_time = datetime.datetime.now()

        diff = finish_time - start_time

        print('took ', diff, ' for this step')
        
    theta, x_without =  simulate_for_sbi(
        simulator_stats,
        proposal=prior_i,
        num_simulations=num_simulations,
        num_workers=8,

    )


    x = sum_stats(x_without)
    inf = inf.append_simulations(theta, x)
    neural_dens = inf.train()

    posterior_incremental = inf.build_posterior(neural_dens) 
    
    posterior_incremental_list.append(posterior_incremental)
# Out:
# 1 2
# Running 1000 simulations in 1000 batches.:   0%|          | 0/1000 [00:00<?, ?it/s]
# /home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/torch/nn/init.py:388: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# Neural network successfully converged after 109 epochs.
# Drawing 1 posterior samples:   0%|          | 0/1 [00:00<?, ?it/s]
# theta shape torch.Size([1, 2])
# took  0:00:09.491037  for this step
# 2 3
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# theta shape torch.Size([1000, 2])
# Running 1000 simulations in 1000 batches.:   0%|          | 0/1000 [00:00<?, ?it/s]
# Neural network successfully converged after 169 epochs.
# Drawing 1 posterior samples:   0%|          | 0/1 [00:00<?, ?it/s]
# theta shape torch.Size([1, 3])
# took  0:00:13.654618  for this step
# 3 4
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# theta shape torch.Size([1000, 3])
# Running 1000 simulations in 1000 batches.:   0%|          | 0/1000 [00:00<?, ?it/s]
# Neural network successfully converged after 150 epochs.
# Drawing 1 posterior samples:   0%|          | 0/1 [00:00<?, ?it/s]
# theta shape torch.Size([1, 4])
# took  0:00:12.835070  for this step
# 4 5
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# theta shape torch.Size([1000, 4])
# Running 1000 simulations in 1000 batches.:   0%|          | 0/1000 [00:00<?, ?it/s]
# Neural network successfully converged after 62 epochs.
# Drawing 1 posterior samples:   0%|          | 0/1 [00:00<?, ?it/s]
# theta shape torch.Size([1, 5])
# took  0:00:06.364169  for this step
# 5 6
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# theta shape torch.Size([1000, 5])
# Running 1000 simulations in 1000 batches.:   0%|          | 0/1000 [00:00<?, ?it/s]
# Neural network successfully converged after 125 epochs.
# Drawing 1 posterior samples:   0%|          | 0/1 [00:00<?, ?it/s]
# theta shape torch.Size([1, 6])
# took  0:00:12.114042  for this step
# 6 7
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# theta shape torch.Size([1000, 6])
# Running 1000 simulations in 1000 batches.:   0%|          | 0/1000 [00:00<?, ?it/s]
# Neural network successfully converged after 82 epochs.
# Drawing 1 posterior samples:   0%|          | 0/1 [00:00<?, ?it/s]
# theta shape torch.Size([1, 7])
# took  0:00:08.822379  for this step
# 7 8
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# theta shape torch.Size([1000, 7])
# Running 1000 simulations in 1000 batches.:   0%|          | 0/1000 [00:00<?, ?it/s]
# Neural network successfully converged after 88 epochs.
# Drawing 1 posterior samples:   0%|          | 0/1 [00:00<?, ?it/s]
# theta shape torch.Size([1, 8])
# took  0:00:09.243709  for this step
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# theta shape torch.Size([1000, 8])
# Running 1000 simulations in 1000 batches.:   0%|          | 0/1000 [00:00<?, ?it/s]
# Neural network successfully converged after 67 epochs.
# 1 2
# Running 3000 simulations in 3000 batches.:   0%|          | 0/3000 [00:00<?, ?it/s]
# Neural network successfully converged after 254 epochs.
# Drawing 1 posterior samples:   0%|          | 0/1 [00:00<?, ?it/s]
# theta shape torch.Size([1, 2])
# took  0:00:50.008662  for this step
# 2 3
# Drawing 3000 posterior samples:   0%|          | 0/3000 [00:00<?, ?it/s]
# theta shape torch.Size([3000, 2])
# Running 3000 simulations in 3000 batches.:   0%|          | 0/3000 [00:00<?, ?it/s]
# Neural network successfully converged after 166 epochs.
# Drawing 1 posterior samples:   0%|          | 0/1 [00:00<?, ?it/s]
# theta shape torch.Size([1, 3])
# took  0:00:38.181466  for this step
# 3 4
# Drawing 3000 posterior samples:   0%|          | 0/3000 [00:00<?, ?it/s]
# theta shape torch.Size([3000, 3])
# Running 3000 simulations in 3000 batches.:   0%|          | 0/3000 [00:00<?, ?it/s]
# Neural network successfully converged after 112 epochs.
# Drawing 1 posterior samples:   0%|          | 0/1 [00:00<?, ?it/s]
# theta shape torch.Size([1, 4])
# took  0:00:27.802281  for this step
# 4 5
# Drawing 3000 posterior samples:   0%|          | 0/3000 [00:00<?, ?it/s]
# theta shape torch.Size([3000, 4])
# Running 3000 simulations in 3000 batches.:   0%|          | 0/3000 [00:00<?, ?it/s]
# Neural network successfully converged after 72 epochs.
# Drawing 1 posterior samples:   0%|          | 0/1 [00:00<?, ?it/s]
# theta shape torch.Size([1, 5])
# took  0:00:19.086162  for this step
# 5 6
# Drawing 3000 posterior samples:   0%|          | 0/3000 [00:00<?, ?it/s]
# theta shape torch.Size([3000, 5])
# Running 3000 simulations in 3000 batches.:   0%|          | 0/3000 [00:00<?, ?it/s]
# Neural network successfully converged after 113 epochs.
# Drawing 1 posterior samples:   0%|          | 0/1 [00:00<?, ?it/s]
# theta shape torch.Size([1, 6])
# took  0:00:31.913871  for this step
# 6 7
# Drawing 3000 posterior samples:   0%|          | 0/3000 [00:00<?, ?it/s]
# theta shape torch.Size([3000, 6])
# Running 3000 simulations in 3000 batches.:   0%|          | 0/3000 [00:00<?, ?it/s]
# Neural network successfully converged after 131 epochs.
# Drawing 1 posterior samples:   0%|          | 0/1 [00:00<?, ?it/s]
# theta shape torch.Size([1, 7])
# took  0:00:36.731843  for this step
# 7 8
# Drawing 3000 posterior samples:   0%|          | 0/3000 [00:00<?, ?it/s]
# theta shape torch.Size([3000, 7])
# Running 3000 simulations in 3000 batches.:   0%|          | 0/3000 [00:00<?, ?it/s]
# Neural network successfully converged after 179 epochs.
# Drawing 1 posterior samples:   0%|          | 0/1 [00:00<?, ?it/s]
# theta shape torch.Size([1, 8])
# took  0:00:50.826756  for this step
# Drawing 3000 posterior samples:   0%|          | 0/3000 [00:00<?, ?it/s]
# theta shape torch.Size([3000, 8])
# Running 3000 simulations in 3000 batches.:   0%|          | 0/3000 [00:00<?, ?it/s]
# Neural network successfully converged after 127 epochs.
# 1 2
# Running 5000 simulations in 5000 batches.:   0%|          | 0/5000 [00:00<?, ?it/s]
# Neural network successfully converged after 188 epochs.
# Drawing 1 posterior samples:   0%|          | 0/1 [00:00<?, ?it/s]
# theta shape torch.Size([1, 2])
# took  0:01:01.919411  for this step
# 2 3
# Drawing 5000 posterior samples:   0%|          | 0/5000 [00:00<?, ?it/s]
# theta shape torch.Size([5000, 2])
# Running 5000 simulations in 5000 batches.:   0%|          | 0/5000 [00:00<?, ?it/s]
# Neural network successfully converged after 148 epochs.
# Drawing 1 posterior samples:   0%|          | 0/1 [00:00<?, ?it/s]
# theta shape torch.Size([1, 3])
# took  0:00:57.622635  for this step
# 3 4
# Drawing 5000 posterior samples:   0%|          | 0/5000 [00:00<?, ?it/s]
# theta shape torch.Size([5000, 3])
# Running 5000 simulations in 5000 batches.:   0%|          | 0/5000 [00:00<?, ?it/s]
# Neural network successfully converged after 230 epochs.
# Drawing 1 posterior samples:   0%|          | 0/1 [00:00<?, ?it/s]
# theta shape torch.Size([1, 4])
# took  0:01:27.326344  for this step
# 4 5
# Drawing 5000 posterior samples:   0%|          | 0/5000 [00:00<?, ?it/s]
# theta shape torch.Size([5000, 4])
# Running 5000 simulations in 5000 batches.:   0%|          | 0/5000 [00:00<?, ?it/s]
# Neural network successfully converged after 170 epochs.
# Drawing 1 posterior samples:   0%|          | 0/1 [00:00<?, ?it/s]
# theta shape torch.Size([1, 5])
# took  0:01:08.841686  for this step
# 5 6
# Drawing 5000 posterior samples:   0%|          | 0/5000 [00:00<?, ?it/s]
# theta shape torch.Size([5000, 5])
# Running 5000 simulations in 5000 batches.:   0%|          | 0/5000 [00:00<?, ?it/s]
# Neural network successfully converged after 33 epochs.
# Drawing 1 posterior samples:   0%|          | 0/1 [00:00<?, ?it/s]
# theta shape torch.Size([1, 6])
# took  0:00:16.916180  for this step
# 6 7
# Drawing 5000 posterior samples:   0%|          | 0/5000 [00:00<?, ?it/s]
# theta shape torch.Size([5000, 6])
# Running 5000 simulations in 5000 batches.:   0%|          | 0/5000 [00:00<?, ?it/s]
# Neural network successfully converged after 199 epochs.
# Drawing 1 posterior samples:   0%|          | 0/1 [00:00<?, ?it/s]
# theta shape torch.Size([1, 7])
# took  0:01:25.070889  for this step
# 7 8
# Drawing 5000 posterior samples:   0%|          | 0/5000 [00:00<?, ?it/s]
# theta shape torch.Size([5000, 7])
# Running 5000 simulations in 5000 batches.:   0%|          | 0/5000 [00:00<?, ?it/s]
# Neural network successfully converged after 31 epochs.
# Drawing 1 posterior samples:   0%|          | 0/1 [00:00<?, ?it/s]
# theta shape torch.Size([1, 8])
# took  0:00:19.167586  for this step
# Drawing 5000 posterior samples:   0%|          | 0/5000 [00:00<?, ?it/s]
# theta shape torch.Size([5000, 8])
# Running 5000 simulations in 5000 batches.:   0%|          | 0/5000 [00:00<?, ?it/s]
# Neural network successfully converged after 270 epochs.
# 1 2
# Running 10000 simulations in 10000 batches.:   0%|          | 0/10000 [00:00<?, ?it/s]
# Neural network successfully converged after 143 epochs.
# Drawing 1 posterior samples:   0%|          | 0/1 [00:00<?, ?it/s]
# theta shape torch.Size([1, 2])
# took  0:01:35.873334  for this step
# 2 3
# Drawing 10000 posterior samples:   0%|          | 0/10000 [00:00<?, ?it/s]
# theta shape torch.Size([10000, 2])
# Running 10000 simulations in 10000 batches.:   0%|          | 0/10000 [00:00<?, ?it/s]
# Neural network successfully converged after 30 epochs.
# Drawing 1 posterior samples:   0%|          | 0/1 [00:00<?, ?it/s]
# theta shape torch.Size([1, 3])
# took  0:00:26.482371  for this step
# 3 4
# Drawing 10000 posterior samples:   0%|          | 0/10000 [00:00<?, ?it/s]
# theta shape torch.Size([10000, 3])
# Running 10000 simulations in 10000 batches.:   0%|          | 0/10000 [00:00<?, ?it/s]
# Neural network successfully converged after 181 epochs.
# Drawing 1 posterior samples:   0%|          | 0/1 [00:00<?, ?it/s]
# theta shape torch.Size([1, 4])
# took  0:02:18.603166  for this step
# 4 5
# Drawing 10000 posterior samples:   0%|          | 0/10000 [00:00<?, ?it/s]
# theta shape torch.Size([10000, 4])
# Running 10000 simulations in 10000 batches.:   0%|          | 0/10000 [00:00<?, ?it/s]
# Neural network successfully converged after 39 epochs.
# Drawing 1 posterior samples:   0%|          | 0/1 [00:00<?, ?it/s]
# theta shape torch.Size([1, 5])
# took  0:00:37.473475  for this step
# 5 6
# Drawing 10000 posterior samples:   0%|          | 0/10000 [00:00<?, ?it/s]
# theta shape torch.Size([10000, 5])
# Running 10000 simulations in 10000 batches.:   0%|          | 0/10000 [00:00<?, ?it/s]
# Neural network successfully converged after 36 epochs.
# Drawing 1 posterior samples:   0%|          | 0/1 [00:00<?, ?it/s]
# theta shape torch.Size([1, 6])
# took  0:00:37.066818  for this step
# 6 7
# Drawing 10000 posterior samples:   0%|          | 0/10000 [00:00<?, ?it/s]
# theta shape torch.Size([10000, 6])
# Running 10000 simulations in 10000 batches.:   0%|          | 0/10000 [00:00<?, ?it/s]
# Neural network successfully converged after 42 epochs.
# Drawing 1 posterior samples:   0%|          | 0/1 [00:00<?, ?it/s]
# theta shape torch.Size([1, 7])
# took  0:00:44.952686  for this step
# 7 8
# Drawing 10000 posterior samples:   0%|          | 0/10000 [00:00<?, ?it/s]
# theta shape torch.Size([10000, 7])
# Running 10000 simulations in 10000 batches.:   0%|          | 0/10000 [00:00<?, ?it/s]
# Neural network successfully converged after 164 epochs.
# Drawing 1 posterior samples:   0%|          | 0/1 [00:00<?, ?it/s]
# theta shape torch.Size([1, 8])
# took  0:02:41.153939  for this step
# Drawing 10000 posterior samples:   0%|          | 0/10000 [00:00<?, ?it/s]
# theta shape torch.Size([10000, 8])
# Running 10000 simulations in 10000 batches.:   0%|          | 0/10000 [00:00<?, ?it/s]
# Neural network successfully converged after 33 epochs.

# %%
import torch.nn.functional as F


#out = F.kl_div(analytic_sample, posterior_sample)

# %%
def calc_KL(posterior):
    
    sample = posterior.sample((10000,))
    
    analytic = torch.distributions.normal.Normal(true_thetas, 0.1)
    
    analytic_sample = analytic.sample((10000,))
    
    out = F.kl_div(analytic_sample, sample)
    
    return out

# %%
KL_snpe = []

for posterior_snpe in posterior_snpe_list:
    
    KL = calc_KL(posterior_snpe)
    
    KL_snpe.append(KL)
# Out:
# Drawing 10000 posterior samples:   0%|          | 0/10000 [00:00<?, ?it/s]
# /home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/torch/nn/functional.py:2742: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# Drawing 10000 posterior samples:   0%|          | 0/10000 [00:00<?, ?it/s]
# Drawing 10000 posterior samples:   0%|          | 0/10000 [00:00<?, ?it/s]
# Drawing 10000 posterior samples:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
KL_incremental = []

for posterior_incremental in posterior_incremental_list:
    
    #posterior_incremental.set_default_x(obs_real_stats)
    
    KL = calc_KL(posterior_incremental)
    
    KL_incremental.append(KL)
# Out:
# Drawing 10000 posterior samples:   0%|          | 0/10000 [00:00<?, ?it/s]
# Drawing 10000 posterior samples:   0%|          | 0/10000 [00:00<?, ?it/s]
# Drawing 10000 posterior samples:   0%|          | 0/10000 [00:00<?, ?it/s]
# Drawing 10000 posterior samples:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
for i, posterior_incremental in enumerate(posterior_incremental_list):
    
    posterior_incremental.set_default_x(obs_real_stats)
    
    torch.save(posterior_incremental, 'posterior_incremental{}.pt'.format(i))
    
for i, posterior_snpe in enumerate(posterior_snpe_list):
    

    torch.save(posterior_snpe, 'posterior_snpe{}.pt'.format(i))

# %%
##load posteriors if already saved:

posterior_snpe0 = torch.load('posterior_snpe0.pt')
posterior_snpe1 = torch.load('posterior_snpe1.pt')
posterior_snpe2 = torch.load('posterior_snpe2.pt')
posterior_snpe3 = torch.load('posterior_snpe3.pt')


posterior_incremental_0 = torch.load('posterior_incremental0.pt')
posterior_incremental_1 = torch.load('posterior_incremental1.pt')
posterior_incremental_2 = torch.load('posterior_incremental2.pt')
posterior_incremental_3 = torch.load('posterior_incremental3.pt')

posterior_snpe_list = [posterior_snpe0, posterior_snpe1, posterior_snpe2, posterior_snpe3]
posterior_incremental_list = [posterior_incremental_0, posterior_incremental_1, posterior_incremental_2, posterior_incremental_3]

# %% [markdown]
# ### Compare KL-divergence of snpe approach with incremental approach in a plot:
#
# #### x = number of simulations per round/step

# %%
figure_mosaic = """
ACC
BCC
"""

fig, axes = plt.subplot_mosaic(mosaic=figure_mosaic, figsize=(11, 5))

axes['B'].plot([1000, 3000, 5000, 10000], KL_incremental, '-o',label='incremental')
axes['A'].plot([1000, 3000, 5000, 10000], KL_snpe, '-o', label='snpe', color='orange')

axes['C'].plot([1000, 3000, 5000, 10000], KL_incremental, '-o', label='incremental')
axes['C'].plot([1000, 3000, 5000, 10000], KL_snpe, '-o', label='snpe', color='orange')

#plt.title('KL loss')
axes['A'].legend()
axes['B'].legend()
axes['C'].legend()

plt.xlabel('simulations per round')


axes['B'].set_xticklabels(['0k','2k', '4k', '6k', '8k', '10k'])
axes['A'].set_xticklabels(['0k','2k', '4k', '6k', '8k', '10k'])
axes['C'].set_xticklabels(['0k','2k', '4k', '6k', '8k', '10k'])
#plt.xticks(['1k', '3k', '5k', '10k'])
# Out:
# /home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/ipykernel_launcher.py:22: UserWarning: FixedFormatter should only be used together with FixedLocator
# /home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator
# /home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: FixedFormatter should only be used together with FixedLocator
# [Text(0.0, 0, '0k'),
#  Text(2000.0, 0, '2k'),
#  Text(4000.0, 0, '4k'),
#  Text(6000.0, 0, '6k'),
#  Text(8000.0, 0, '8k'),
#  Text(10000.0, 0, '10k'),
#  Text(12000.0, 0, '')]
