# %% [markdown]
# # Exploring parameters
#
# #### density plots, post predictive checks etc.

# %%
# %load_ext autoreload
# %autoreload 2
import os.path as op
import tempfile

import matplotlib.pyplot as plt


import hnn_core
from hnn_core import simulate_dipole, jones_2009_model
from hnn_core.viz import plot_dipole


import sys
sys.path.append('../code/')
sys.path.append('../code/utils/')
#sys.path.append('../code/sbi/')
#sys.path.append('../../results_cluster/')


import numpy as np
import torch

# visualization
import matplotlib as mpl
import matplotlib.pyplot as plt


import os

work_dir = '/home/ubuntu/sbi_for_eeg_data/code/'

os.chdir(work_dir)

#from utils.plot import cov, compare_vars, plot_varchanges
#from utils.plot import compare_KLs, plot_KLs
#from sbi.inference import potentials
import utils.sbi_modulated_functions

# sbi
from sbi import utils as utils
from sbi import analysis as analysis
from sbi.inference.base import infer
from sbi.inference import SNPE, prepare_for_sbi, simulate_for_sbi

from sbi.analysis import conditional_pairplot, conditional_corrcoeff



# import the summary statistics that you want to investigate
from summary_features.calculate_summary_features import calculate_summary_statistics_alternative as alternative_sumstats
from summary_features.calculate_summary_features import calculate_summary_stats_temporal as temporal_sumstats
from summary_features.calculate_summary_features import calculate_summary_stats_number as number_sumstats
from summary_features.calculate_summary_features import calculate_summary_stats_temporal

# %%
print(torch.__version__)
# Out:
# 1.9.1+cu102

# %%
## defining neuronal network model

num_params = 6

from utils.simulation_wrapper import set_network_default, SimulationWrapper
sim_wrapper = SimulationWrapper(num_params, noise=False)

# %%
from utils import inference

import pickle
from data_load_writer import *
from data_load_writer import load_from_file as lf

import os

work_dir = '/home/ubuntu/'

os.chdir(work_dir)



import os

print(os.getcwd())



file = 'toy_example_mdn_seperate_posteriors'


print(os.getcwd())

os.chdir('results/{}'.format(file))


print(os.getcwd())
# Out:
# /home/ubuntu
# /home/ubuntu
# /home/ubuntu/results/toy_example_mdn_seperate_posteriors

# %%
def Gaussian(thetas, normal_noise=1):
    
    gauss_list = []
    
    for theta in thetas:
    
        mu, sigma = theta, normal_noise # mean and standard deviation

        s = np.random.normal(mu, sigma, 1)
    
        
        gauss_list.append(s[0])
        
    gauss_obs = torch.tensor(gauss_list)
    
    return gauss_obs

# %%
list_collection = torch.load('list_collection.pt')
list_collection_inc = torch.load('list_collection_inc.pt')

# %%
prior_max = [100.0] * 15
prior_min = [1.0] * 15

prior = utils.torchutils.BoxUniform(low=prior_min, high = prior_max)

samples_prior = prior.sample((1000,))

simulator_stats, prior = prepare_for_sbi(Gaussian, prior)

# %%
samples_prior
# Out:
# tensor([[ 5.7010, 27.0259,  5.0373,  ..., 42.2281, 41.9627, 61.7241],
#         [83.6912, 83.3554, 54.1466,  ...,  1.5988, 96.3168, 47.3201],
#         [51.3180, 71.0872, 85.3685,  ..., 47.0234, 40.4246, 60.6584],
#         ...,
#         [79.8510, 93.4582, 45.6095,  ..., 19.5998, 58.3513,  1.8776],
#         [82.3954, 35.7635, 41.4466,  ..., 88.1406, 83.3973, 14.8846],
#         [23.3497, 92.9961, 93.3811,  ..., 57.4545, 22.3189, 19.4755]])

# %%
thetas = inference.run_only_sim([samples_prior], simulation_wrapper = simulator_stats, num_workers=1)[0]
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s finished

# %%
thetas[0]
# Out:
# tensor([ 6.2866, 28.0083,  4.4211, 12.2337, 96.1799, 25.6631,  8.8217, 50.4921,
#         35.4895, 39.7052, 49.0321, 48.6248, 41.8453, 42.0683, 62.6820])

# %%
from sbi.analysis.sbc import check_sbc, run_sbc, get_nltp
from sbi.analysis.plot import sbc_rank_plot
from sbi.inference import SNPE, SNPE_C, prepare_for_sbi, simulate_for_sbi
from sbi.simulators import linear_gaussian, diagonal_linear_gaussian

# %%
#thetas = torch.stack(([samples_prior[i] for i in range(len(samples_prior))]))
xs = samples_prior

# %%
xs.shape
# Out:
# torch.Size([1000, 15])

# %%
posterior = list_collection_inc[0][0]

# %%
posterior.sample((1,))
# Out:
# Drawing 1 posterior samples:   0%|          | 0/1 [00:00<?, ?it/s]
# Drawing 1 posterior samples:   0%|          | 0/1 [00:00<?, ?it/s]
# Drawing 1 posterior samples:   0%|          | 0/1 [00:00<?, ?it/s]
# tensor([[23.7461, 41.8398, 18.1123, 24.1536, 29.6302, 89.2399, 39.0001, 16.0574,
#          16.6525, 56.4845,  7.3383, 59.0395, 91.0058, 43.3553, 46.8586]])

# %%
# run SBC: for each inference we draw 1000 posterior samples.
num_posterior_samples = 300
ranks, dap_samples = run_sbc(thetas, xs, posterior, num_posterior_samples=num_posterior_samples)

check_stats = check_sbc(ranks, thetas, dap_samples, num_posterior_samples=num_posterior_samples)


print(f"kolmogorov-smirnov p-values \ncheck_stats['ks_pvals'] = {check_stats['ks_pvals'].numpy()}")
# Out:
# Running 1000 sbc samples.:   0%|          | 0/1000 [00:00<?, ?it/s]
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# assertion error
# /home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 752, in fit
#     return self._fit(X, y, incremental=False)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 393, in _fit
#     X, y = self._validate_input(X, y, incremental, reset=first_pass)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1106, in _validate_input
#     reset=reset,
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/base.py", line 572, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 968, in check_X_y
#     estimator=estimator,
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 792, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 116, in _assert_all_finite
#     type_err, msg_dtype if msg_dtype is not None else X.dtype
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 752, in fit
#     return self._fit(X, y, incremental=False)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 393, in _fit
#     X, y = self._validate_input(X, y, incremental, reset=first_pass)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1106, in _validate_input
#     reset=reset,
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/base.py", line 572, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 968, in check_X_y
#     estimator=estimator,
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 792, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 116, in _assert_all_finite
#     type_err, msg_dtype if msg_dtype is not None else X.dtype
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 752, in fit
#     return self._fit(X, y, incremental=False)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 393, in _fit
#     X, y = self._validate_input(X, y, incremental, reset=first_pass)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1106, in _validate_input
#     reset=reset,
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/base.py", line 572, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 968, in check_X_y
#     estimator=estimator,
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 792, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 116, in _assert_all_finite
#     type_err, msg_dtype if msg_dtype is not None else X.dtype
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 752, in fit
#     return self._fit(X, y, incremental=False)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 393, in _fit
#     X, y = self._validate_input(X, y, incremental, reset=first_pass)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1106, in _validate_input
#     reset=reset,
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/base.py", line 572, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 968, in check_X_y
#     estimator=estimator,
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 792, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 116, in _assert_all_finite
#     type_err, msg_dtype if msg_dtype is not None else X.dtype
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 752, in fit
#     return self._fit(X, y, incremental=False)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 393, in _fit
#     X, y = self._validate_input(X, y, incremental, reset=first_pass)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1106, in _validate_input
#     reset=reset,
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/base.py", line 572, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 968, in check_X_y
#     estimator=estimator,
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 792, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 116, in _assert_all_finite
#     type_err, msg_dtype if msg_dtype is not None else X.dtype
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 752, in fit
#     return self._fit(X, y, incremental=False)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 393, in _fit
#     X, y = self._validate_input(X, y, incremental, reset=first_pass)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1106, in _validate_input
#     reset=reset,
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/base.py", line 572, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 968, in check_X_y
#     estimator=estimator,
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 792, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 116, in _assert_all_finite
#     type_err, msg_dtype if msg_dtype is not None else X.dtype
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 752, in fit
#     return self._fit(X, y, incremental=False)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 393, in _fit
#     X, y = self._validate_input(X, y, incremental, reset=first_pass)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1106, in _validate_input
#     reset=reset,
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/base.py", line 572, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 968, in check_X_y
#     estimator=estimator,
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 792, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 116, in _assert_all_finite
#     type_err, msg_dtype if msg_dtype is not None else X.dtype
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 752, in fit
#     return self._fit(X, y, incremental=False)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 393, in _fit
#     X, y = self._validate_input(X, y, incremental, reset=first_pass)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1106, in _validate_input
#     reset=reset,
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/base.py", line 572, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 968, in check_X_y
#     estimator=estimator,
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 792, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 116, in _assert_all_finite
#     type_err, msg_dtype if msg_dtype is not None else X.dtype
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 752, in fit
#     return self._fit(X, y, incremental=False)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 393, in _fit
#     X, y = self._validate_input(X, y, incremental, reset=first_pass)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1106, in _validate_input
#     reset=reset,
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/base.py", line 572, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 968, in check_X_y
#     estimator=estimator,
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 792, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 116, in _assert_all_finite
#     type_err, msg_dtype if msg_dtype is not None else X.dtype
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 752, in fit
#     return self._fit(X, y, incremental=False)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 393, in _fit
#     X, y = self._validate_input(X, y, incremental, reset=first_pass)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1106, in _validate_input
#     reset=reset,
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/base.py", line 572, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 968, in check_X_y
#     estimator=estimator,
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 792, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 116, in _assert_all_finite
#     type_err, msg_dtype if msg_dtype is not None else X.dtype
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 752, in fit
#     return self._fit(X, y, incremental=False)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 393, in _fit
#     X, y = self._validate_input(X, y, incremental, reset=first_pass)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1106, in _validate_input
#     reset=reset,
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/base.py", line 572, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 968, in check_X_y
#     estimator=estimator,
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 792, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 116, in _assert_all_finite
#     type_err, msg_dtype if msg_dtype is not None else X.dtype
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 752, in fit
#     return self._fit(X, y, incremental=False)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 393, in _fit
#     X, y = self._validate_input(X, y, incremental, reset=first_pass)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1106, in _validate_input
#     reset=reset,
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/base.py", line 572, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 968, in check_X_y
#     estimator=estimator,
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 792, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 116, in _assert_all_finite
#     type_err, msg_dtype if msg_dtype is not None else X.dtype
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 752, in fit
#     return self._fit(X, y, incremental=False)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 393, in _fit
#     X, y = self._validate_input(X, y, incremental, reset=first_pass)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1106, in _validate_input
#     reset=reset,
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/base.py", line 572, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 968, in check_X_y
#     estimator=estimator,
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 792, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 116, in _assert_all_finite
#     type_err, msg_dtype if msg_dtype is not None else X.dtype
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 752, in fit
#     return self._fit(X, y, incremental=False)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 393, in _fit
#     X, y = self._validate_input(X, y, incremental, reset=first_pass)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1106, in _validate_input
#     reset=reset,
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/base.py", line 572, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 968, in check_X_y
#     estimator=estimator,
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 792, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 116, in _assert_all_finite
#     type_err, msg_dtype if msg_dtype is not None else X.dtype
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 752, in fit
#     return self._fit(X, y, incremental=False)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 393, in _fit
#     X, y = self._validate_input(X, y, incremental, reset=first_pass)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 1106, in _validate_input
#     reset=reset,
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/base.py", line 572, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 968, in check_X_y
#     estimator=estimator,
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 792, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "/home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/sklearn/utils/validation.py", line 116, in _assert_all_finite
#     type_err, msg_dtype if msg_dtype is not None else X.dtype
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)

# %%
print(f"c2st accuracies \ncheck_stats['c2st_ranks'] = {check_stats['c2st_ranks'].numpy()}")
print(f"- c2st accuracies check_stats['c2st_dap'] = {check_stats['c2st_dap'].numpy()}")
# Out:
# c2st accuracies
# check_stats['c2st_ranks'] = [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
# - c2st accuracies check_stats['c2st_dap'] = [0.98  0.975 0.97  0.97  0.955 0.975 0.96  0.965 0.965 0.97  0.975 0.975
#  0.975 0.99  0.98 ]

# %%
from sbi.analysis.plot import sbc_rank_plot

f, ax = sbc_rank_plot(ranks=ranks,
                      num_posterior_samples=num_posterior_samples,
                      plot_type="hist",
                      num_bins=10 # by passing None we use a heuristic for the number of bins.
                      )

# %%
f, ax = sbc_rank_plot(ranks, 1_000, plot_type = "cdf")
