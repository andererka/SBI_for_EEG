# %% [markdown]
# # Thesis Fig.4.6: Density plots and correlation matrices for SNPE

# %%
# %load_ext autoreload
# %autoreload 2
import os.path as op
import tempfile

import matplotlib.pyplot as plt


import hnn_core
from hnn_core import simulate_dipole, jones_2009_model
from hnn_core.viz import plot_dipole


import sys
sys.path.append('../code/')
sys.path.append('../code/utils/')
#sys.path.append('../code/sbi/')
#sys.path.append('../../results_cluster/')


import numpy as np
import torch

# visualization
import matplotlib as mpl
import matplotlib.pyplot as plt


import os

work_dir = '/home/ubuntu/sbi_for_eeg_data/code/'

os.chdir(work_dir)

#from utils.plot import cov, compare_vars, plot_varchanges
#from utils.plot import compare_KLs, plot_KLs
#from sbi.inference import potentials
import utils.sbi_modulated_functions

# sbi
from sbi import utils as utils
from sbi import analysis as analysis
from sbi.inference.base import infer
from sbi.inference import SNPE, prepare_for_sbi, simulate_for_sbi

from sbi.analysis import conditional_pairplot, conditional_corrcoeff



# import the summary statistics that you want to investigate
from summary_features.calculate_summary_features import calculate_summary_statistics_alternative as alternative_sumstats
from summary_features.calculate_summary_features import calculate_summary_stats_temporal as temporal_sumstats
from summary_features.calculate_summary_features import calculate_summary_stats_number as number_sumstats
from summary_features.calculate_summary_features import calculate_summary_stats_temporal

# %%
print(torch.__version__)
# Out:
# 1.11.0

# %%
## defining neuronal network model

num_params = 17

from utils.simulation_wrapper import set_network_default, SimulationWrapper
sim_wrapper = SimulationWrapper(num_params, noise=False)

# %%
window_len = 30

if num_params == 6:
    
    prior_min_fix = [0.0, 11.3, 0.0, 43.8, 0.0, 89.491]
    prior_max_fix = [0.160, 35.9, 0.821, 79.0, 8.104, 162.110]

    prior_min = [0.0, 11.3, 0.0, 43.8, 0.0, 89.491]
    prior_max = [0.160, 35.9, 0.821, 79.0, 8.104, 162.110]
    #true_params = torch.tensor([[26.61, 63.53,  137.12]])
    true_params = torch.tensor([[0.0274, 19.01, 0.1369, 61.89, 0.1435, 120.86]])

    

if num_params == 25:
    prior_min = [0, 0, 0, 0, 0, 0, 0, 0, 13.3,    # prox1 weights
                 0, 0, 0, 0, 0, 0, 51.980,            # distal weights
                 0, 0, 0, 0, 0, 0, 0, 0, 112.13]       # prox2 weights


    # ampa, nmda [0.927, 0.160, 2.093, 0.0519,        1.0, 1.0, 1.0, 1.0, 35.9,
    #           0.0394, 0.000042, 0.039372,           0.854, 0.117,  0.480, 75.08,
    #            0.000018, 8.633, 0.05375, 4.104,     1.0, 1.0, 1.0, 1.0, 162.110]

    prior_max = [0.927, 1.0, 0.160, 1.0,  2.093, 1.0, 0.0519, 1.0, 35.9,
                 0.0394, 0.117, 0.000042, 0.025902, 0.854, 0.480, 75.08,
                 0.000018, 1.0, 8.633, 1.0, 0.05375, 1.0, 4.104,  1.0, 162.110]

    true_params = torch.tensor([[0.277, 0.3739, 0.0399, 0.0, 0.6244, 0.3739, 0.034, 0.0, 18.977,
                                 0.011467, 0.06337, 0.000012, 0.013407, 0.466095, 0.0767, 63.08,
                                 0.000005, 0.116706, 4.6729, 0.016733, 0.011468, 0.061556, 2.33, 0.0679, 120.86]])
    
if num_params == 17:
    
    prior_min = [0, 0, 0, 0, 0, 13.3,  0, 0, 0, 0, 0, 51.980, 0, 0, 0, 0, 112.13]
    prior_max = [0.927, 0.160, 2.093, 1.0, 1.0, 35.9, 0.000042, 0.039372, 0.025902,  0.480, 0.117, 75.08, 8.633, 4.104, 1.0, 1.0, 162.110]

    true_params = torch.tensor([[0.277, 0.0399, 0.6244, 0.3739, 0.0, 18.977, 0.000012, 0.0115, 0.0134,  0.0767, 0.06337, 63.08, 4.6729, 2.33, 0.016733, 0.0679, 120.86]])


prior = utils.torchutils.BoxUniform(low=prior_min, high=prior_max)

#number_simulations = 10
density_estimator = 'nsf'

# %%
prior = torch.distributions.uniform.Uniform(torch.tensor(prior_min), torch.tensor(prior_max))

# %%
from utils import inference

# %%
from utils import inference

import pickle
from data_load_writer import *
from data_load_writer import load_from_file as lf

import os

work_dir = '/home/ubuntu/'

os.chdir(work_dir)



import os


file = 'multi_round_17params'



print(os.getcwd())

os.chdir('results')


print(os.getcwd())
  

thetas = torch.load('{}/thetas.pt'.format(file))

posterior = torch.load('{}/posterior.pt'.format(file))
# Out:
# /home/ubuntu
# /home/ubuntu/results

# %%
#obs_real_stat2 = calculate_summary_stats_temporal(obs_real[0])

samples = posterior.sample((1000,), not_within_prior=False)
# Out:
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# /home/ubuntu/miniconda3/envs/sbi_env/lib/python3.7/site-packages/nflows/transforms/lu.py:81: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at  /opt/conda/conda-bld/pytorch_1646755861072/work/aten/src/ATen/native/BatchLinearAlgebra.cpp:1672.)
#   outputs.t(), lower, upper=False, unitriangular=True
# acceptance rate:  0.0
# WARNING:root:Drawing samples from posterior to estimate the normalizing
#                         constant for `log_prob()`. However, only
#                         0% posterior samples are within the
#                         prior support. It may take a long time to collect the
#                         remaining 1000 samples.
#                         Consider interrupting (Ctrl-C) and either basing the
#                         estimate of the normalizing constant on fewer samples (by
#                         calling `posterior.leakage_correction(x_o,
#                         num_rejection_samples=N)`, where `N` is the number of
#                         samples you want to base the
#                         estimate on (default N=10000), or not estimating the
#                         normalizing constant at all
#                         (`log_prob(..., norm_posterior=False)`. The latter will
#                         result in an unnormalized `log_prob()`.
# acceptance rate:  0.0
# acceptance rate:  9.523809523809524e-05
# acceptance rate:  9.67741935483871e-05
# acceptance rate:  7.317073170731707e-05
# acceptance rate:  7.843137254901961e-05
# acceptance rate:  9.836065573770491e-05
# acceptance rate:  9.859154929577464e-05
# acceptance rate:  8.641975308641975e-05
# acceptance rate:  7.692307692307693e-05
# acceptance rate:  6.93069306930693e-05
# acceptance rate:  7.207207207207208e-05
# acceptance rate:  7.43801652892562e-05
# acceptance rate:  7.633587786259542e-05
# acceptance rate:  7.092198581560284e-05
# acceptance rate:  7.284768211920529e-05
# acceptance rate:  6.832298136645963e-05
# acceptance rate:  7.017543859649122e-05
# acceptance rate:  7.18232044198895e-05
# acceptance rate:  7.329842931937172e-05
# acceptance rate:  6.965174129353234e-05
# acceptance rate:  7.582938388625592e-05
# acceptance rate:  8.144796380090498e-05
# acceptance rate:  9.09090909090909e-05
# acceptance rate:  9.54356846473029e-05
# acceptance rate:  9.960159362549801e-05
# acceptance rate:  9.961685823754789e-05
# acceptance rate:  9.59409594095941e-05
# acceptance rate:  9.608540925266904e-05
# acceptance rate:  9.278350515463917e-05
# acceptance rate:  8.970099667774087e-05
# acceptance rate:  9.003215434083602e-05
# acceptance rate:  8.722741433021807e-05
# acceptance rate:  8.459214501510574e-05
# acceptance rate:  8.211143695014662e-05
# acceptance rate:  8.547008547008547e-05
# acceptance rate:  8.587257617728532e-05
# acceptance rate:  8.62533692722372e-05
# acceptance rate:  8.398950131233596e-05
# acceptance rate:  8.184143222506395e-05
# acceptance rate:  8.229426433915212e-05
# acceptance rate:  8.515815085158151e-05
# acceptance rate:  8.551068883610452e-05
# acceptance rate:  8.816705336426914e-05
# acceptance rate:  8.843537414965987e-05
# acceptance rate:  8.869179600886918e-05
# acceptance rate:  8.893709327548807e-05
# acceptance rate:  9.129511677282378e-05
# acceptance rate:  9.355509355509356e-05
# acceptance rate:  9.164969450101833e-05
# acceptance rate:  9.3812375249501e-05
# acceptance rate:  9.197651663405088e-05
# acceptance rate:  9.021113243761996e-05
# acceptance rate:  9.03954802259887e-05
# acceptance rate:  9.057301293900185e-05
# acceptance rate:  8.892921960072595e-05
# acceptance rate:  8.734402852049911e-05
# acceptance rate:  8.581436077057794e-05
# acceptance rate:  8.433734939759036e-05
# acceptance rate:  8.629441624365482e-05
# acceptance rate:  8.818635607321132e-05
# acceptance rate:  9.001636661211129e-05
# acceptance rate:  8.856682769726247e-05
# acceptance rate:  8.874801901743265e-05
# acceptance rate:  8.736349453978159e-05
# acceptance rate:  8.755760368663595e-05
# acceptance rate:  8.774583963691377e-05
# acceptance rate:  8.792846497764531e-05
# acceptance rate:  8.81057268722467e-05
# acceptance rate:  8.683068017366137e-05
# acceptance rate:  8.701854493580599e-05
# acceptance rate:  8.720112517580872e-05
# acceptance rate:  8.599167822468793e-05
# acceptance rate:  8.618331053351573e-05
# acceptance rate:  8.771929824561403e-05
# acceptance rate:  8.655126498002663e-05
# acceptance rate:  8.672798948751643e-05
# acceptance rate:  8.560311284046692e-05
# acceptance rate:  8.450704225352113e-05
# acceptance rate:  8.343868520859671e-05
# acceptance rate:  8.614232209737827e-05
# acceptance rate:  8.508014796547472e-05
# acceptance rate:  8.526187576126675e-05
# acceptance rate:  8.543922984356197e-05
# acceptance rate:  8.561236623067776e-05
# acceptance rate:  8.578143360752056e-05
# acceptance rate:  8.478513356562137e-05
# acceptance rate:  8.381171067738231e-05
# acceptance rate:  8.286038592508513e-05
# acceptance rate:  8.305274971941638e-05
# acceptance rate:  8.213096559378469e-05
# acceptance rate:  8.45225027442371e-05
# acceptance rate:  8.360477741585234e-05
# acceptance rate:  8.378088077336197e-05
# acceptance rate:  8.289054197662062e-05
# acceptance rate:  8.201892744479495e-05
# acceptance rate:  8.116545265348596e-05
# acceptance rate:  8.135942327497425e-05
# acceptance rate:  8.256880733944954e-05
# acceptance rate:  8.173562058526741e-05
# acceptance rate:  8.391608391608392e-05
# acceptance rate:  8.308605341246291e-05
# acceptance rate:  8.325171400587659e-05
# acceptance rate:  8.341416100872939e-05
# acceptance rate:  8.261287223823248e-05
# acceptance rate:  8.277830637488107e-05
# acceptance rate:  8.294062205466542e-05
# acceptance rate:  8.30999066293184e-05
# acceptance rate:  8.325624421831638e-05
# acceptance rate:  8.340971585701192e-05
# acceptance rate:  8.265213442325159e-05
# acceptance rate:  8.19081908190819e-05
# acceptance rate:  8.117752007136485e-05
# acceptance rate:  8.222811671087533e-05
# acceptance rate:  8.238387379491674e-05
# acceptance rate:  8.253692441355343e-05
# acceptance rate:  8.2687338501292e-05
# acceptance rate:  8.368915456874466e-05
# acceptance rate:  8.298052497883149e-05
# acceptance rate:  8.312342569269522e-05
# acceptance rate:  8.243130724396337e-05
# acceptance rate:  8.422791081750619e-05
# acceptance rate:  8.353808353808354e-05
# acceptance rate:  8.285946385052803e-05
# acceptance rate:  8.219178082191781e-05
# acceptance rate:  8.15347721822542e-05
# acceptance rate:  8.088818398096748e-05
# acceptance rate:  8.025177025963808e-05
# acceptance rate:  7.962529274004684e-05
# acceptance rate:  7.900852052672348e-05
# acceptance rate:  7.840122982321291e-05
# acceptance rate:  7.780320366132724e-05
# acceptance rate:  7.797123391370174e-05
# acceptance rate:  7.738542449286251e-05
# acceptance rate:  7.829977628635347e-05
# acceptance rate:  7.846039970392303e-05
# acceptance rate:  7.788390889052167e-05
# acceptance rate:  7.731582786287381e-05
# acceptance rate:  7.748008689355539e-05
# acceptance rate:  7.692307692307693e-05
# acceptance rate:  7.708779443254818e-05
# acceptance rate:  7.725017717930546e-05
# acceptance rate:  7.741027445460944e-05
# acceptance rate:  7.82669461914745e-05
# acceptance rate:  7.84177654406662e-05
# acceptance rate:  7.856650585802895e-05
# acceptance rate:  7.871321013004791e-05
# acceptance rate:  7.817811012916384e-05
# acceptance rate:  7.765023632680622e-05
# acceptance rate:  7.712944332662643e-05
# acceptance rate:  7.794803464357095e-05
# acceptance rate:  7.743216412971542e-05
# acceptance rate:  7.692307692307693e-05
# acceptance rate:  7.642064010450686e-05
# acceptance rate:  7.657365347177158e-05
# acceptance rate:  7.672469374597034e-05
# acceptance rate:  7.687379884689302e-05
# acceptance rate:  7.702100572883514e-05
# acceptance rate:  7.653383934218849e-05
# acceptance rate:  7.668133249528599e-05
# acceptance rate:  7.682698313554029e-05
# acceptance rate:  7.635009310986964e-05
# acceptance rate:  7.649599012954966e-05
# acceptance rate:  7.602697731453096e-05
# acceptance rate:  7.556368068251066e-05
# acceptance rate:  7.631738340399758e-05
# acceptance rate:  7.645996387718242e-05
# acceptance rate:  7.660083782166367e-05
# acceptance rate:  7.674003569303986e-05
# acceptance rate:  7.628622117090479e-05
# acceptance rate:  7.642563198118753e-05
# acceptance rate:  7.656341320864992e-05
# acceptance rate:  7.611853573503777e-05
# acceptance rate:  7.625649913344887e-05
# acceptance rate:  7.581849511774842e-05
# acceptance rate:  7.538549400342661e-05
# acceptance rate:  7.60931289040318e-05
# acceptance rate:  7.622811970638058e-05
# acceptance rate:  7.63615946097698e-05
# acceptance rate:  7.649357900614182e-05
# acceptance rate:  7.773459189339256e-05
# acceptance rate:  7.730535615681944e-05
# acceptance rate:  7.688083470620538e-05
# acceptance rate:  7.700709994538503e-05
# acceptance rate:  7.658881042911461e-05
# acceptance rate:  7.671528903295516e-05
# acceptance rate:  7.684040838259001e-05
# acceptance rate:  7.74986638161411e-05
# acceptance rate:  7.708665603402445e-05
# acceptance rate:  7.773664727657324e-05
# acceptance rate:  7.78537611783272e-05
# acceptance rate:  7.744636316064887e-05
# acceptance rate:  7.704320666319625e-05
# acceptance rate:  7.664422578974624e-05
# acceptance rate:  7.624935600206079e-05
# acceptance rate:  7.585853408508457e-05
# acceptance rate:  7.598164201937786e-05
# acceptance rate:  7.661085743277524e-05
# acceptance rate:  7.62241292276628e-05
# acceptance rate:  7.584128578603716e-05
# acceptance rate:  7.596201899050474e-05
# acceptance rate:  7.558428642466434e-05
# acceptance rate:  7.570509648688767e-05
# acceptance rate:  7.533234859675037e-05
# acceptance rate:  7.496325330720236e-05
# acceptance rate:  7.459775719161384e-05
# acceptance rate:  7.423580786026201e-05
# acceptance rate:  7.436021245774988e-05
# acceptance rate:  7.400288322921672e-05
# acceptance rate:  7.41272118603539e-05
# acceptance rate:  7.425035697287006e-05
# acceptance rate:  7.437233538607296e-05
# acceptance rate:  7.402168788307402e-05
# acceptance rate:  7.414359455654622e-05
# acceptance rate:  7.426436244745446e-05
# acceptance rate:  7.438400743840075e-05
# acceptance rate:  7.403979639055993e-05
# acceptance rate:  7.415937356057117e-05
# acceptance rate:  7.38193489225126e-05
# acceptance rate:  7.348242811501597e-05
# acceptance rate:  7.314856883234894e-05
# acceptance rate:  7.372229760289462e-05
# acceptance rate:  7.339036470058532e-05
# acceptance rate:  7.395786642761094e-05
# acceptance rate:  7.407407407407407e-05
# acceptance rate:  7.418924922256774e-05
# acceptance rate:  7.430340557275542e-05
# acceptance rate:  7.441655658300309e-05
# acceptance rate:  7.452871547566857e-05
# acceptance rate:  7.507638585770406e-05
# acceptance rate:  7.518470230334637e-05
# acceptance rate:  7.572479446127218e-05
# acceptance rate:  7.539853511417492e-05
# acceptance rate:  7.55040755040755e-05
# acceptance rate:  7.518154634771465e-05
# acceptance rate:  7.528711186729051e-05
# acceptance rate:  7.496823379923761e-05
# acceptance rate:  7.465204555040068e-05
# acceptance rate:  7.47585048299034e-05
# acceptance rate:  7.444583856127143e-05
# acceptance rate:  7.413577675968346e-05
# acceptance rate:  7.382828701783493e-05
# acceptance rate:  7.393638992152003e-05
# acceptance rate:  7.404360345536816e-05
# acceptance rate:  7.37402703809914e-05
# acceptance rate:  7.343941248470012e-05
# acceptance rate:  7.314099959366111e-05
# acceptance rate:  7.324969647915823e-05
# acceptance rate:  7.335751713018944e-05
# acceptance rate:  7.306302689682858e-05
# acceptance rate:  7.357057177129149e-05
# acceptance rate:  7.327757865392273e-05
# acceptance rate:  7.298690995636652e-05
# acceptance rate:  7.309363887791387e-05
# acceptance rate:  7.280598189689099e-05
# acceptance rate:  7.29125833006664e-05
# acceptance rate:  7.262787973447871e-05
# acceptance rate:  7.234539089848308e-05
# acceptance rate:  7.206509104998063e-05
# acceptance rate:  7.178695484368969e-05
# acceptance rate:  7.151095732410611e-05
# acceptance rate:  7.123707391803907e-05
# acceptance rate:  7.096528042731782e-05
# acceptance rate:  7.069555302166477e-05
# acceptance rate:  7.04278682317304e-05
# acceptance rate:  7.053941908713692e-05
# acceptance rate:  7.027433295753476e-05
# acceptance rate:  7.03856233620367e-05
# acceptance rate:  7.01230883998508e-05
# acceptance rate:  6.986250464511334e-05
# acceptance rate:  6.960385042576824e-05
# acceptance rate:  6.971597196606419e-05
# acceptance rate:  6.982726938625505e-05
# acceptance rate:  6.993775173928964e-05
# acceptance rate:  7.00474279460051e-05
# acceptance rate:  7.015630679752818e-05
# acceptance rate:  6.990220934444042e-05
# acceptance rate:  6.964994586791772e-05
# acceptance rate:  6.939949658396261e-05
# acceptance rate:  6.915084199211752e-05
# acceptance rate:  6.890396287040343e-05
# acceptance rate:  6.865884027036642e-05
# acceptance rate:  6.912442396313364e-05
# acceptance rate:  6.923348640056518e-05
# acceptance rate:  6.934178106300598e-05
# acceptance rate:  6.909856190810243e-05
# acceptance rate:  6.920657112897589e-05
# acceptance rate:  6.93138279345176e-05
# acceptance rate:  6.907323845886845e-05
# acceptance rate:  6.88343133863715e-05
# acceptance rate:  6.859703550499828e-05
# acceptance rate:  6.83613878392305e-05
# acceptance rate:  6.812735364601164e-05
# acceptance rate:  6.82360968952576e-05
# acceptance rate:  6.834410064603877e-05
# acceptance rate:  6.845137241613012e-05
# acceptance rate:  6.855791962174941e-05
# acceptance rate:  6.832716257152474e-05
# acceptance rate:  6.843341160684334e-05
# acceptance rate:  6.853895018388498e-05
# acceptance rate:  6.864378540486505e-05
# acceptance rate:  6.841580870142809e-05
# acceptance rate:  6.852035749751738e-05
# acceptance rate:  6.829429231276806e-05
# acceptance rate:  6.806971390989806e-05
# acceptance rate:  6.784660766961652e-05
# acceptance rate:  6.860503103560927e-05
# acceptance rate:  6.870726147834582e-05
# acceptance rate:  6.848425835767608e-05
# acceptance rate:  6.858621805241022e-05
# acceptance rate:  6.836504353434376e-05
# acceptance rate:  6.878817100610737e-05
# acceptance rate:  6.920858699134893e-05
# acceptance rate:  6.93069306930693e-05
# acceptance rate:  6.94046482012098e-05
# acceptance rate:  6.950174547762615e-05
# acceptance rate:  6.928187282505536e-05
# acceptance rate:  6.906338694418165e-05
# acceptance rate:  6.884627475636592e-05
# acceptance rate:  6.925728611720464e-05
# acceptance rate:  6.90409247110278e-05
# acceptance rate:  6.913734039240113e-05
# acceptance rate:  6.892269481527476e-05
# acceptance rate:  6.870937790157846e-05
# acceptance rate:  6.880592409750077e-05
# acceptance rate:  6.890187634573977e-05
# acceptance rate:  6.869058570990494e-05
# acceptance rate:  6.878630388260471e-05
# acceptance rate:  6.888143858579701e-05
# acceptance rate:  6.867213612883623e-05
# acceptance rate:  6.876704029082096e-05
# acceptance rate:  6.855934762911507e-05
# acceptance rate:  6.89551339957844e-05
# acceptance rate:  6.87481236865806e-05
# acceptance rate:  6.884166417240348e-05
# acceptance rate:  6.863622799164428e-05
# acceptance rate:  6.902707527521571e-05
# acceptance rate:  6.911895579946603e-05
# acceptance rate:  6.89145223306714e-05
# acceptance rate:  6.871129460336183e-05
# acceptance rate:  6.850926198177006e-05
# acceptance rate:  6.830841395485195e-05
# acceptance rate:  6.810874013446361e-05
# acceptance rate:  6.820169046925094e-05
# acceptance rate:  6.800348735832606e-05
# acceptance rate:  6.838597507968704e-05
# acceptance rate:  6.876625252817105e-05
# acceptance rate:  6.885623739556324e-05
# acceptance rate:  6.952025280091928e-05
# acceptance rate:  6.932111142938985e-05
# acceptance rate:  6.9123107683519e-05
# acceptance rate:  6.949587012247223e-05
# acceptance rate:  7.015052541891508e-05
# acceptance rate:  6.995185499858397e-05
# acceptance rate:  6.975430669302457e-05
# acceptance rate:  6.98394818361025e-05
# acceptance rate:  6.964335860713282e-05
# acceptance rate:  7.000840100812098e-05
# acceptance rate:  6.981290142418318e-05
# acceptance rate:  6.961849067112225e-05
# acceptance rate:  6.970286031657872e-05
# acceptance rate:  6.97867626696206e-05
# acceptance rate:  6.95940347970174e-05
# acceptance rate:  6.940236849352795e-05
# acceptance rate:  6.948640483383686e-05
# acceptance rate:  6.956998082717063e-05
# acceptance rate:  6.93799508331057e-05
# acceptance rate:  6.91909561427404e-05
# acceptance rate:  6.927465362673187e-05
# acceptance rate:  6.935789758872934e-05
# acceptance rate:  6.91704944609565e-05
# acceptance rate:  6.898410132039881e-05
# acceptance rate:  6.879871002418704e-05
# acceptance rate:  6.861431251675154e-05
# acceptance rate:  6.843090082865544e-05
# acceptance rate:  6.851506264996001e-05
# acceptance rate:  6.833289018877958e-05
# acceptance rate:  6.815168390347388e-05
# acceptance rate:  6.82359164242264e-05
# acceptance rate:  6.831970456343973e-05
# acceptance rate:  6.840305182846619e-05
# acceptance rate:  6.848596168984518e-05
# acceptance rate:  6.856843758178488e-05
# acceptance rate:  6.865048290263639e-05
# acceptance rate:  6.873210101536058e-05
# acceptance rate:  6.855362243573097e-05
# acceptance rate:  6.863506863506864e-05
# acceptance rate:  6.871609403254973e-05
# acceptance rate:  6.879670188095852e-05
# acceptance rate:  6.861989205859677e-05
# acceptance rate:  6.870033324788515e-05
# acceptance rate:  6.852467399642036e-05
# acceptance rate:  6.834991073705687e-05
# acceptance rate:  6.817603663190028e-05
# acceptance rate:  6.800304491245877e-05
# acceptance rate:  6.808402935965579e-05
# acceptance rate:  6.81646048977531e-05
# acceptance rate:  6.799294887937547e-05
# acceptance rate:  6.782215523737755e-05
# acceptance rate:  6.790278125783012e-05
# acceptance rate:  6.773306673331668e-05
# acceptance rate:  6.781351283969085e-05
# acceptance rate:  6.764486446157672e-05
# acceptance rate:  6.747705284048624e-05
# acceptance rate:  6.829992576095026e-05
# acceptance rate:  6.813132559861762e-05
# acceptance rate:  6.796355577443979e-05
# acceptance rate:  6.779661016949152e-05
# acceptance rate:  6.763048272482234e-05
# acceptance rate:  6.746516744072354e-05
# acceptance rate:  6.75445013411363e-05
# acceptance rate:  6.738019946485041e-05
# acceptance rate:  6.770201407425382e-05
# acceptance rate:  6.778019849915275e-05
# acceptance rate:  6.761651774933592e-05
# acceptance rate:  6.793543724403759e-05
# acceptance rate:  6.801249699591445e-05
# acceptance rate:  6.784943658595061e-05
# acceptance rate:  6.816551064338676e-05
# acceptance rate:  6.824146981627296e-05
# acceptance rate:  6.807902880266603e-05
# acceptance rate:  6.791735929707908e-05
# acceptance rate:  6.775645581615731e-05
# acceptance rate:  6.759631292838573e-05
# acceptance rate:  6.743692525347796e-05
# acceptance rate:  6.751352622912256e-05
# acceptance rate:  6.782445435343817e-05
# acceptance rate:  6.766565207211426e-05
# acceptance rate:  6.750759168418594e-05
# acceptance rate:  6.735026800279655e-05
# acceptance rate:  6.742617995814927e-05
# acceptance rate:  6.750173973556019e-05
# acceptance rate:  6.757694978014348e-05
# acceptance rate:  6.742091895636112e-05
# acceptance rate:  6.749596867081318e-05
# acceptance rate:  6.734084118593427e-05
# acceptance rate:  6.718642513185049e-05
# acceptance rate:  6.703271562571494e-05
# acceptance rate:  6.687970782926273e-05
# acceptance rate:  6.69551355044409e-05
# acceptance rate:  6.680299931833674e-05
# acceptance rate:  6.687825889820903e-05
# acceptance rate:  6.672698484505768e-05
# acceptance rate:  6.680207628074927e-05
# acceptance rate:  6.710200405314119e-05
# acceptance rate:  6.695124691080656e-05
# acceptance rate:  6.680116565792423e-05
# acceptance rate:  6.665175575933796e-05
# acceptance rate:  6.650301272037492e-05
# acceptance rate:  6.657759964373191e-05
# acceptance rate:  6.642968229282381e-05
# acceptance rate:  6.628242074927953e-05
# acceptance rate:  6.613581066135811e-05
# acceptance rate:  6.621054954756124e-05
# acceptance rate:  6.628495926007487e-05
# acceptance rate:  6.635904196879807e-05
# acceptance rate:  6.621354966016225e-05
# acceptance rate:  6.672500546926275e-05
# acceptance rate:  6.657934948701157e-05
# acceptance rate:  6.643432803310825e-05
# acceptance rate:  6.628993697022386e-05
# acceptance rate:  6.61461721969204e-05
# acceptance rate:  6.60030296472625e-05
# acceptance rate:  6.586050529043403e-05
# acceptance rate:  6.571859513035984e-05
# acceptance rate:  6.600731025585896e-05
# acceptance rate:  6.58656940570693e-05
# acceptance rate:  6.572468422179405e-05
# acceptance rate:  6.579790643024994e-05
# acceptance rate:  6.608399062033682e-05
# acceptance rate:  6.594341629440544e-05
# acceptance rate:  6.580343876034812e-05
# acceptance rate:  6.566405422579962e-05
# acceptance rate:  6.552525893045868e-05
# acceptance rate:  6.559797511073614e-05
# acceptance rate:  6.545990317827826e-05
# acceptance rate:  6.553245116572149e-05
# acceptance rate:  6.539509536784741e-05
# acceptance rate:  6.546747542355156e-05
# acceptance rate:  6.533082863702775e-05
# acceptance rate:  6.54030410331181e-05
# acceptance rate:  6.52670962377884e-05
# acceptance rate:  6.533914125700062e-05
# acceptance rate:  6.520389153384392e-05
# acceptance rate:  6.50692005783929e-05
# acceptance rate:  6.514120799835086e-05
# acceptance rate:  6.500720016457519e-05
# acceptance rate:  6.52843358653254e-05
# acceptance rate:  6.535545994673223e-05
# acceptance rate:  6.522183602535268e-05
# acceptance rate:  6.54968373801265e-05
# acceptance rate:  6.556709427815109e-05
# acceptance rate:  6.563706563706564e-05
# acceptance rate:  6.55039545731089e-05
# acceptance rate:  6.537138231127302e-05
# acceptance rate:  6.523934558675015e-05
# acceptance rate:  6.530941342471277e-05
# acceptance rate:  6.55803661235164e-05
# acceptance rate:  6.56494679783176e-05
# acceptance rate:  6.571829292726908e-05
# acceptance rate:  6.59868026394721e-05
# acceptance rate:  6.605467970464977e-05
# acceptance rate:  6.592312288388768e-05
# acceptance rate:  6.5792089047903e-05
# acceptance rate:  6.566157508430867e-05
# acceptance rate:  6.553157790536528e-05
# acceptance rate:  6.559968385694527e-05
# acceptance rate:  6.566752119897456e-05
# acceptance rate:  6.573509151741784e-05
# acceptance rate:  6.599882144961697e-05
# acceptance rate:  6.60654773573809e-05
# acceptance rate:  6.593621600469575e-05
# acceptance rate:  6.639328256199961e-05
# acceptance rate:  6.626388618203079e-05
# acceptance rate:  6.6134993191986e-05
# acceptance rate:  6.639487478159581e-05
# acceptance rate:  6.645998837434605e-05
# acceptance rate:  6.633146393347515e-05
# acceptance rate:  6.620343563018723e-05
# acceptance rate:  6.626854170680024e-05
# acceptance rate:  6.614112670640262e-05
# acceptance rate:  6.601420072922664e-05
# acceptance rate:  6.58877609653323e-05
# acceptance rate:  6.595297266297075e-05
# acceptance rate:  6.58271322266743e-05
# acceptance rate:  6.589221100742716e-05
# acceptance rate:  6.576696445542673e-05
# acceptance rate:  6.58319104534244e-05
# acceptance rate:  6.570725241431547e-05
# acceptance rate:  6.577206577206578e-05
# acceptance rate:  6.58366345972458e-05
# acceptance rate:  6.571267181321785e-05
# acceptance rate:  6.558917496711145e-05
# acceptance rate:  6.58413055711874e-05
# acceptance rate:  6.571803033139862e-05
# acceptance rate:  6.578209680433564e-05
# acceptance rate:  6.565939190449543e-05
# acceptance rate:  6.572332898901507e-05
# acceptance rate:  6.560118937000558e-05
# acceptance rate:  6.585049156000742e-05
# acceptance rate:  6.57285687835586e-05
# acceptance rate:  6.597671410090556e-05
# acceptance rate:  6.585500830105147e-05
# acceptance rate:  6.59178788436752e-05
# acceptance rate:  6.598051828707958e-05
# acceptance rate:  6.585947532562833e-05
# acceptance rate:  6.628822559970702e-05
# acceptance rate:  6.634984463535002e-05
# acceptance rate:  6.62287903667214e-05
# acceptance rate:  6.61081770169368e-05
# acceptance rate:  6.616978731139793e-05
# acceptance rate:  6.623117401560516e-05
# acceptance rate:  6.611121173700417e-05
# acceptance rate:  6.617248237208462e-05
# acceptance rate:  6.60530590146183e-05
# acceptance rate:  6.611421365519726e-05
# acceptance rate:  6.617514835461249e-05
# acceptance rate:  6.605636330999821e-05
# acceptance rate:  6.593800394194588e-05
# acceptance rate:  6.635664460740475e-05
# acceptance rate:  6.623817175504374e-05
# acceptance rate:  6.629834254143647e-05
# acceptance rate:  6.635829923501157e-05
# acceptance rate:  6.624045462617652e-05
# acceptance rate:  6.63003013650062e-05
# acceptance rate:  6.635993629446116e-05
# acceptance rate:  6.64193605370076e-05
# acceptance rate:  6.630223946393934e-05
# acceptance rate:  6.618553071642316e-05
# acceptance rate:  6.642066420664207e-05
# acceptance rate:  6.647956498859849e-05
# acceptance rate:  6.653825949921204e-05
# acceptance rate:  6.694633805278797e-05
# acceptance rate:  6.700401326121096e-05
# acceptance rate:  6.706148754572374e-05
# acceptance rate:  6.694487915145192e-05
# acceptance rate:  6.682867557715675e-05
# acceptance rate:  6.671287471841968e-05
# acceptance rate:  6.677045493859194e-05
# acceptance rate:  6.665515455016405e-05
# acceptance rate:  6.65402516807447e-05
# acceptance rate:  6.659783169850285e-05
# acceptance rate:  6.648342209242398e-05
# acceptance rate:  6.636940490481907e-05
# acceptance rate:  6.62557781201849e-05
# acceptance rate:  6.614253973679713e-05
# acceptance rate:  6.637092646306091e-05
# acceptance rate:  6.642820643842616e-05
# acceptance rate:  6.6655330726067e-05
# acceptance rate:  6.6711933457817e-05
# acceptance rate:  6.676834434841553e-05
# acceptance rate:  6.682456437151074e-05
# acceptance rate:  6.688059449417329e-05
# acceptance rate:  6.676783004552352e-05
# acceptance rate:  6.682376704258542e-05
# acceptance rate:  6.671147706267854e-05
# acceptance rate:  6.659956383157189e-05
# acceptance rate:  6.665550159102328e-05
# acceptance rate:  6.654405617789668e-05
# acceptance rate:  6.676681689200467e-05
# acceptance rate:  6.665555740709882e-05
# acceptance rate:  6.65446681084678e-05
# acceptance rate:  6.643414715163594e-05
# acceptance rate:  6.64898026861217e-05
# acceptance rate:  6.637973845389837e-05
# acceptance rate:  6.643529995042142e-05
# acceptance rate:  6.632568883022604e-05
# acceptance rate:  6.654587382638775e-05
# acceptance rate:  6.660088801184016e-05
# acceptance rate:  6.649154490231489e-05
# acceptance rate:  6.638256023602688e-05
# acceptance rate:  6.62739322533137e-05
# acceptance rate:  6.616565920601208e-05
# acceptance rate:  6.622084488664166e-05
# acceptance rate:  6.61130109102752e-05
# acceptance rate:  6.600552755649488e-05
# acceptance rate:  6.622301574419737e-05
# acceptance rate:  6.611570247933885e-05
# acceptance rate:  6.600873645041256e-05
# acceptance rate:  6.590211597480213e-05
# acceptance rate:  6.579583938074503e-05
# acceptance rate:  6.585090967638061e-05
# acceptance rate:  6.574505706478058e-05
# acceptance rate:  6.563954421441182e-05
# acceptance rate:  6.553436949206857e-05
# acceptance rate:  6.5429531274996e-05
# acceptance rate:  6.548474684555183e-05
# acceptance rate:  6.538032211768458e-05
# acceptance rate:  6.52762298996975e-05
# acceptance rate:  6.5172468605945e-05
# acceptance rate:  6.506903666084749e-05
# acceptance rate:  6.528283948661068e-05
# acceptance rate:  6.51795601961715e-05
# acceptance rate:  6.523456010108988e-05
# acceptance rate:  6.51316826998896e-05
# acceptance rate:  6.534404030861281e-05
# acceptance rate:  6.524131425876435e-05
# acceptance rate:  6.51389106890598e-05
# acceptance rate:  6.519354333176619e-05
# acceptance rate:  6.524800500704115e-05
# acceptance rate:  6.530229651616934e-05
# acceptance rate:  6.520043674933708e-05
# acceptance rate:  6.509889425323158e-05
# acceptance rate:  6.499766754781527e-05
# acceptance rate:  6.505201055736687e-05
# acceptance rate:  6.510618508758332e-05
# acceptance rate:  6.51601919207553e-05
# acceptance rate:  6.521403183433782e-05
# acceptance rate:  6.526770560098751e-05
# acceptance rate:  6.532121398859959e-05
# acceptance rate:  6.552838024919243e-05
# acceptance rate:  6.542773767470434e-05
# acceptance rate:  6.532740377242754e-05
# acceptance rate:  6.538049303322616e-05
# acceptance rate:  6.528053814401467e-05
# acceptance rate:  6.51808884139826e-05
# acceptance rate:  6.508154244779759e-05
# acceptance rate:  6.513468269669761e-05
# acceptance rate:  6.503570885883604e-05
# acceptance rate:  6.493703535123654e-05
# acceptance rate:  6.483866080896834e-05
# acceptance rate:  6.474058387535926e-05
# acceptance rate:  6.464280320193324e-05
# acceptance rate:  6.454531744834867e-05
# acceptance rate:  6.4448125282337e-05
# acceptance rate:  6.435122537964216e-05
# acceptance rate:  6.425461642396036e-05
# acceptance rate:  6.415829710688053e-05
# acceptance rate:  6.406226612782518e-05
# acceptance rate:  6.396652219399194e-05
# acceptance rate:  6.416952693627817e-05
# acceptance rate:  6.422291759797347e-05
# acceptance rate:  6.412736199970242e-05
# acceptance rate:  6.418065666320012e-05
# acceptance rate:  6.408544726301736e-05
# acceptance rate:  6.399051992297437e-05
# acceptance rate:  6.404378050584233e-05
# acceptance rate:  6.409688376901491e-05
# acceptance rate:  6.400235953399203e-05
# acceptance rate:  6.420262111618318e-05
# acceptance rate:  6.425525657991472e-05
# acceptance rate:  6.445455880193805e-05
# acceptance rate:  6.450667057616185e-05
# acceptance rate:  6.455862977602107e-05
# acceptance rate:  6.446425961116796e-05
# acceptance rate:  6.43701649394249e-05
# acceptance rate:  6.442209590438712e-05
# acceptance rate:  6.447387570950371e-05
# acceptance rate:  6.438017729981108e-05
# acceptance rate:  6.428675083442171e-05
# acceptance rate:  6.433850166642515e-05
# acceptance rate:  6.424540587469252e-05
# acceptance rate:  6.415257910706545e-05
# acceptance rate:  6.420429952387823e-05
# acceptance rate:  6.411179945252845e-05
# acceptance rate:  6.401956553013955e-05
# acceptance rate:  6.421491165062491e-05
# acceptance rate:  6.426624587577105e-05
# acceptance rate:  6.431743303251683e-05
# acceptance rate:  6.422543269918467e-05
# acceptance rate:  6.441936866161977e-05
# acceptance rate:  6.461275139067181e-05
# acceptance rate:  6.452072354365474e-05
# acceptance rate:  6.442895747404352e-05
# acceptance rate:  6.447947734696776e-05
# acceptance rate:  6.452985392142958e-05
# acceptance rate:  6.472171080583487e-05
# acceptance rate:  6.463017960684486e-05
# acceptance rate:  6.453890693404887e-05
# acceptance rate:  6.458891552672401e-05
# acceptance rate:  6.449795803407971e-05
# acceptance rate:  6.468851075798059e-05
# acceptance rate:  6.473809858165987e-05
# acceptance rate:  6.478754732856542e-05
# acceptance rate:  6.469682117350511e-05
# acceptance rate:  6.488602992588449e-05
# acceptance rate:  6.479541963412932e-05
# acceptance rate:  6.470506205550132e-05
# acceptance rate:  6.461495613424314e-05
# acceptance rate:  6.452510082047004e-05
# acceptance rate:  6.45743646715734e-05
# acceptance rate:  6.462349188739425e-05
# acceptance rate:  6.453399806121037e-05
# acceptance rate:  6.4583045221961e-05
# acceptance rate:  6.449385443999447e-05
# acceptance rate:  6.440490966763205e-05
# acceptance rate:  6.431620988844512e-05
# acceptance rate:  6.464035208361986e-05
# acceptance rate:  6.455157258618322e-05
# acceptance rate:  6.460019201755589e-05
# acceptance rate:  6.451171072455827e-05
# acceptance rate:  6.469703186978526e-05
# acceptance rate:  6.460866001912307e-05
# acceptance rate:  6.452052925930978e-05
# acceptance rate:  6.456885982836126e-05
# acceptance rate:  6.448102299006938e-05
# acceptance rate:  6.439342480641217e-05
# acceptance rate:  6.471306471306472e-05
# acceptance rate:  6.503183850426771e-05
# acceptance rate:  6.494385062914356e-05
# acceptance rate:  6.485610052695582e-05
# acceptance rate:  6.476858723519094e-05
# acceptance rate:  6.481606252526613e-05
# acceptance rate:  6.48634100390257e-05
# acceptance rate:  6.491063029162747e-05
# acceptance rate:  6.495772379546369e-05
# acceptance rate:  6.487066076933387e-05
# acceptance rate:  6.505153259269173e-05
# acceptance rate:  6.509824889720625e-05
# acceptance rate:  6.514484047523695e-05
# acceptance rate:  6.519130782562325e-05
# acceptance rate:  6.510451338037545e-05
# acceptance rate:  6.501794974072597e-05
# acceptance rate:  6.506440047802417e-05
# acceptance rate:  6.497811961278345e-05
# acceptance rate:  6.50245000662164e-05
# acceptance rate:  6.507075783626504e-05
# acceptance rate:  6.49848104609695e-05
# acceptance rate:  6.516290726817042e-05
# acceptance rate:  6.507706494533e-05
# acceptance rate:  6.499144849361927e-05
# acceptance rate:  6.490605702273027e-05
# acceptance rate:  6.482088964702795e-05
# acceptance rate:  6.473594548551958e-05
# acceptance rate:  6.465122366182437e-05
# acceptance rate:  6.469742517317998e-05
# acceptance rate:  6.47435060697037e-05
# acceptance rate:  6.46591057228523e-05
# acceptance rate:  6.457492513995574e-05
# acceptance rate:  6.449096346378884e-05
# acceptance rate:  6.440721984157902e-05
# acceptance rate:  6.432369342497731e-05
# acceptance rate:  6.42403833700298e-05
# acceptance rate:  6.415728883714913e-05
# acceptance rate:  6.407440899108642e-05
# acceptance rate:  6.424977422268095e-05
# acceptance rate:  6.42958381651849e-05
# acceptance rate:  6.421309998713164e-05
# acceptance rate:  6.41305744762884e-05
# acceptance rate:  6.417661404184315e-05
# acceptance rate:  6.409434687860531e-05
# acceptance rate:  6.401229035974907e-05
# acceptance rate:  6.405830456463367e-05
# acceptance rate:  6.41042012514366e-05
# acceptance rate:  6.402244611656676e-05
# acceptance rate:  6.406827155776335e-05
# acceptance rate:  6.41139804096171e-05
# acceptance rate:  6.403252445686699e-05
# acceptance rate:  6.407816266971196e-05
# acceptance rate:  6.399695856038524e-05
# acceptance rate:  6.391596000506265e-05
# acceptance rate:  6.383516622424472e-05
# acceptance rate:  6.400706981441738e-05
# acceptance rate:  6.405245240196697e-05
# acceptance rate:  6.397179196574739e-05
# acceptance rate:  6.414287511004905e-05
# acceptance rate:  6.40623037306871e-05
# acceptance rate:  6.423284405971647e-05
# acceptance rate:  6.415236185941611e-05
# acceptance rate:  6.407208109122762e-05
# acceptance rate:  6.41169853768279e-05
# acceptance rate:  6.416177755586069e-05
# acceptance rate:  6.420645804762499e-05
# acceptance rate:  6.425102726933134e-05
# acceptance rate:  6.42954856361149e-05
# acceptance rate:  6.421562538815053e-05
# acceptance rate:  6.426001736757226e-05
# acceptance rate:  6.430429934332797e-05
# acceptance rate:  6.422472466278926e-05
# acceptance rate:  6.4268940798418e-05
# acceptance rate:  6.431304777188002e-05
# acceptance rate:  6.42337566268031e-05
# acceptance rate:  6.415466075606452e-05
# acceptance rate:  6.419874554175378e-05
# acceptance rate:  6.436555705687262e-05
# acceptance rate:  6.428659060238007e-05
# acceptance rate:  6.420781766940326e-05
# acceptance rate:  6.412923754742381e-05
# acceptance rate:  6.405084952939739e-05
# acceptance rate:  6.40947381272128e-05
# acceptance rate:  6.401658334349469e-05
# acceptance rate:  6.39386189258312e-05
# acceptance rate:  6.38608441795402e-05
# acceptance rate:  6.378325841331551e-05
# acceptance rate:  6.382720543623347e-05
# acceptance rate:  6.374984850321173e-05
# acceptance rate:  6.367267885243917e-05
# acceptance rate:  6.359569580461854e-05
# acceptance rate:  6.363965704625045e-05
# acceptance rate:  6.368351224219032e-05
# acceptance rate:  6.360679436212504e-05
# acceptance rate:  6.353026109974733e-05
# acceptance rate:  6.345391178944838e-05
# acceptance rate:  6.361781298763653e-05
# acceptance rate:  6.354154178156096e-05
# acceptance rate:  6.346545323913304e-05
# acceptance rate:  6.33895467049396e-05
# acceptance rate:  6.331382152669932e-05
# acceptance rate:  6.3238277055244e-05
# acceptance rate:  6.328208795137647e-05
# acceptance rate:  6.332579454826806e-05
# acceptance rate:  6.33693972179289e-05
# acceptance rate:  6.329414558840993e-05
# acceptance rate:  6.333768236270905e-05
# acceptance rate:  6.326264660585239e-05
# acceptance rate:  6.318778842740504e-05
# acceptance rate:  6.311310719773077e-05
# acceptance rate:  6.303860229016645e-05
# acceptance rate:  6.29642730810046e-05
# acceptance rate:  6.300789070780827e-05
# acceptance rate:  6.293377249735325e-05
# acceptance rate:  6.285982845729056e-05
# acceptance rate:  6.278605797441615e-05
# acceptance rate:  6.271246043840113e-05
# acceptance rate:  6.27561175506381e-05
# acceptance rate:  6.279967255291778e-05
# acceptance rate:  6.272631701903983e-05
# acceptance rate:  6.300315015750788e-05
# acceptance rate:  6.29297284698753e-05
# acceptance rate:  6.28564777092306e-05
# acceptance rate:  6.278339727938612e-05
# acceptance rate:  6.271048658692371e-05
# acceptance rate:  6.263774504117852e-05
# acceptance rate:  6.268103348395319e-05
# acceptance rate:  6.26084943872237e-05

# %%
torch.save(samples,'samples_multi.pt')

# %%
parameter_names = ["prox1_ampa_l2_bas","prox1_ampa_l2_pyr","prox1_ampa_l5_bas","prox1_nmda_l5_bas", "prox1_nmda_l5_pyr",
 "t_prox1",
 "dist_ampa_l2_pyr","dist_ampa_l2_bas","dist_nmda_l2_pyr",
 "dist_nmda_l5_pyr","dist_nmda_l2_bas",
 "t_dist", 
 "prox2_ampa_l2_pyr","prox2_ampa_l5_pyr","prox2_nmda_l2_pyr","prox2_nmda_l5_pyr",
 "t_prox2"]

if num_params ==6:
    parameter_names = ["prox_1_ampa_l2_pyr",
     "t_evprox_1",
     "dist_nmda_l2_pyr",
     "t_evdist_1", 
     "prox_2_ampa_l5_pyr",
     "t_evprox_2"]

# %%
##better limits:

list_min = torch.min(samples, 0)[0]
list_max = torch.max(samples, 0)[0]

print(list_min)

print(list_max)

diff = torch.abs(list_max - list_min) * 0.1

print(diff)

list_min = list(torch.nn.functional.relu(list_min) - diff)
#list_min = list(list_min - diff)
list_max = list(list_max + diff)

limits = [list(tup) for tup in zip(list_min, list_max)]
# Out:
# tensor([2.7430e-03, 1.0554e-03, 3.1096e-03, 5.6658e-03, 3.3953e-07, 1.7363e+01,
#         1.1431e-08, 8.0272e-07, 2.2893e-04, 4.6837e-02, 3.0217e-04, 5.9955e+01,
#         3.5040e-02, 7.1623e-01, 2.1728e-04, 3.7528e-05, 1.1407e+02])
# tensor([3.8879e-01, 1.5012e-01, 2.0923e+00, 7.8126e-01, 3.9626e-03, 2.7149e+01,
#         4.1976e-05, 3.9356e-02, 2.5896e-02, 1.8565e-01, 1.1699e-01, 6.4397e+01,
#         8.6291e+00, 4.0952e+00, 9.9598e-01, 2.0003e-01, 1.2470e+02])
# tensor([3.8605e-02, 1.4907e-02, 2.0892e-01, 7.7559e-02, 3.9622e-04, 9.7856e-01,
#         4.1965e-06, 3.9355e-03, 2.5667e-03, 1.3882e-02, 1.1669e-02, 4.4427e-01,
#         8.5940e-01, 3.3789e-01, 9.9576e-02, 1.9999e-02, 1.0631e+00])

# %%
##better limits:
list_max2 = torch.cat((true_params[0].unsqueeze(0), torch.tensor(list_max).unsqueeze(0)), dim=0) 
list_max3 = torch.max(list_max2, 0)

list_min2 = torch.cat((true_params[0].unsqueeze(0), torch.tensor(list_min).unsqueeze(0)), dim=0) 
list_min3 = torch.min(list_min2, 0)

limits = [list(tup) for tup in zip(list_min3.values, list_max3.values)]

# %%
#limits = [list(tup) for tup in zip(prior_min, prior_max)]


plt.set_cmap('viridis')

fig, axes = analysis.pairplot(
    samples,
    limits=limits,
    upper = 'kde',
    lower='kde',
    #subset=[5, 11, 16],
    ticks=np.round(limits,2),
    figsize=(20, 20),
    points=true_params,
    points_offdiag={"markersize": 5},
    points_colors="r",
    labels=parameter_names,
)

# %%
corr_matrix_marginal = np.corrcoef(samples.T)
fig, ax = plt.subplots(1,1, figsize=(4, 4))
im = plt.imshow(corr_matrix_marginal, clim=[-1, 1], cmap='PiYG')
_ = fig.colorbar(im)

# %%
cond_coeff_mat_list = []


## for the conditional correlation matrix, we had to take the posterior from the second round because leakage was too huge 
## for the third round

#posteriors_round =  torch.load('{}/posteriors_each_round.pt'.format(file))

#posterior = posteriors_round[1]

for i in range(5):
    condition = posterior.sample((1,))
    cond_coeff_mat = conditional_corrcoeff(
        density=posterior,
        condition=condition,
        limits=torch.tensor([[-2., 2.]]*17),
    )
    cond_coeff_mat_list.append(cond_coeff_mat)
# Out:
# Drawing 1 posterior samples:   0%|          | 0/1 [00:00<?, ?it/s]
# acceptance rate:  0.0
# WARNING:root:Drawing samples from posterior to estimate the normalizing
#                         constant for `log_prob()`. However, only
#                         0% posterior samples are within the
#                         prior support. It may take a long time to collect the
#                         remaining -1 samples.
#                         Consider interrupting (Ctrl-C) and either basing the
#                         estimate of the normalizing constant on fewer samples (by
#                         calling `posterior.leakage_correction(x_o,
#                         num_rejection_samples=N)`, where `N` is the number of
#                         samples you want to base the
#                         estimate on (default N=10000), or not estimating the
#                         normalizing constant at all
#                         (`log_prob(..., norm_posterior=False)`. The latter will
#                         result in an unnormalized `log_prob()`.
# acceptance rate:  0.00019998000199980003
# WARNING:root:Drawing samples from posterior to estimate the normalizing
#                         constant for `log_prob()`. However, only
#                         0% posterior samples are within the
#                         prior support. It may take a long time to collect the
#                         remaining 10000 samples.
#                         Consider interrupting (Ctrl-C) and either basing the
#                         estimate of the normalizing constant on fewer samples (by
#                         calling `posterior.leakage_correction(x_o,
#                         num_rejection_samples=N)`, where `N` is the number of
#                         samples you want to base the
#                         estimate on (default N=10000), or not estimating the
#                         normalizing constant at all
#                         (`log_prob(..., norm_posterior=False)`. The latter will
#                         result in an unnormalized `log_prob()`.
# acceptance rate:  0.0
# acceptance rate:  5e-05
# acceptance rate:  6.666666666666667e-05
# acceptance rate:  5e-05
# acceptance rate:  4e-05
# acceptance rate:  5e-05
# acceptance rate:  4.2857142857142856e-05
# acceptance rate:  5e-05
# acceptance rate:  4.4444444444444447e-05

# %%
cond_coeff_mat_tensor = torch.stack(cond_coeff_mat_list, dim=0)

#take average:
cond_coeff_mat_av = torch.nanmean(cond_coeff_mat_tensor, dim=0)

fig, ax = plt.subplots(1,1, figsize=(4,4))
im = plt.imshow(cond_coeff_mat_av, clim=[-1, 1], cmap='PiYG')
_ = fig.colorbar(im)
